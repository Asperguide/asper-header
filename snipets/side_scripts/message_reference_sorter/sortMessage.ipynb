# %%
"""
@file sortMessages.py
@brief Python script to sort messageReference.ts entries alphabetically for each language
@author Henry Letellier
@date 2025-10-05

This script reads the messageReference.ts file and sorts all message entries
alphabetically within each language section while preserving the exact
function signatures and implementations.
"""
# Out:
# '\n@file sortMessages.py\n@brief Python script to sort messageReference.ts entries alphabetically for each language\n@author Henry Letellier\n@date 2025-10-05\n\nThis script reads the messageReference.ts file and sorts all message entries\nalphabetically within each language section while preserving the exact\nfunction signatures and implementations.\n'

# %%
# Import dependencies
import re
import os
import sys
from typing import List, Dict, Optional, NamedTuple, Union
import shutil
from pathlib import Path

# %%
# The file to process
FILE_PATH: str = os.path.abspath(
    os.path.join(
        os.getcwd(),
        "..",
        "..",
        "..",
        "vscode",
        "asperheader",
        "src",
        "modules",
        "messageReference.ts"
    )
)
# This is just debug info to provide a bit of data for you if you wish
print(f"Input file: {FILE_PATH}")
print(f"Path exists: {os.path.exists(FILE_PATH)}")
print(f"Path points to a file: {os.path.isfile(FILE_PATH)}")
# Out:
# Input file: /home/eletellier/Documents/001_github/Asperguide/asper-header/vscode/asperheader/src/modules/messageReference.ts
# Path exists: True
# Path points to a file: True

# %%
# The output name
OUTPUT_NAME: str = os.path.abspath(
    os.path.join(
        os.getcwd(),
        "..",
        "..",
        "..",
        "vscode",
        "asperheader",
        "src",
        "modules",
        "messageReference_sorted.ts"
    )
)
# This is just debug info to provide a bit of data for you if you wish
print(f"Output file: {OUTPUT_NAME}")
print(f"Path exists: {os.path.exists(OUTPUT_NAME)}")
print(f"Path points to a file: {os.path.isfile(OUTPUT_NAME)}")
# Out:
# Output file: /home/eletellier/Documents/001_github/Asperguide/asper-header/vscode/asperheader/src/modules/messageReference_sorted.ts
# Path exists: False
# Path points to a file: False

# %%
# Define structures
## MessageEntry
class MessageEntry(NamedTuple):
    key: str
    full_content: str

# %%
## LanguageSection
class LanguageSection(NamedTuple):
    language: str
    start_line: int
    end_line: int
    entries: List[MessageEntry]

# %%
# Class in charge of sorting the messages in the nodes

class MessageSorter:
    def __init__(self, file_path: str, output_file: str):
        self.output_file = output_file
        self.file_path = file_path
        with open(file_path, 'r', encoding='utf-8') as f:
            self.content = f.read()
        self.lines = self.content.split('\n')

    def extract_language_section(self, language_code: str) -> Optional[LanguageSection]:
        """Extract a complete language section with all its message entries"""
        lang_pattern = f'"{language_code}": {{'
        start_line = -1

        # Find the start of the language section
        for i, line in enumerate(self.lines):
            if lang_pattern in line:
                start_line = i
                break

        if start_line == -1:
            print(f"Warning: Language {language_code} not found")
            return None

        # Find the end of the language section
        end_line = -1
        for i in range(start_line + 1, len(self.lines)):
            line = self.lines[i].strip()
            # Look for next language or closing brace
            if ((line.startswith('"') and '": {' in line and not line.startswith('        ')) or line == '},'):
                end_line = i
                break

        if end_line == -1:
            print(f"Warning: End of language {language_code} not found")
            return None

        # Extract message entries
        entries = []
        i = start_line + 1

        while i < end_line:
            line = self.lines[i]

            # Check if this line starts a message entry
            if line.strip() and line.startswith('        ') and ':' in line:
                key_match = re.match(r'^\s+([a-zA-Z][a-zA-Z0-9]*): ', line)

                if key_match:
                    key = key_match.group(1)
                    entry_lines = [line]
                    j = i + 1

                    # Collect all lines belonging to this entry (multi-line support)
                    while j < end_line:
                        next_line = self.lines[j]

                        # Check if we've reached the next entry
                        if (next_line.strip() and next_line.startswith('        ') and re.match(r'^\s+[a-zA-Z][a-zA-Z0-9]*: ', next_line)):
                            break

                        entry_lines.append(next_line)
                        j += 1

                    # Join the entry and clean it up
                    full_content = '\n'.join(entry_lines).rstrip()

                    # Ensure proper comma handling
                    if not full_content.endswith(','):
                        full_content += ','

                    entries.append(MessageEntry(key, full_content))
                    i = j
                else:
                    i += 1
            else:
                i += 1

        return LanguageSection(language_code, start_line, end_line, entries)

    def create_sorted_section(self, section: LanguageSection) -> List[str]:
        """Sort entries alphabetically and create new section content"""
        # Sort entries by key
        sorted_entries = sorted(section.entries, key=lambda x: x.key.lower())

        # Create new section lines
        new_lines = []
        new_lines.append(self.lines[section.start_line])  # Opening line: "lang": {

        # Add sorted entries
        for i, entry in enumerate(sorted_entries):
            entry_content = entry.full_content

            # Remove comma from last entry
            if i == len(sorted_entries) - 1:
                entry_content = re.sub(r',\s*$', '', entry_content)

            new_lines.append(entry_content)

        new_lines.append('    },')  # Closing line

        return new_lines

    def sort_all_languages(self) -> None:
        """Sort all language sections in the file"""
        languages = [
            'en', 'fr', 'it', 'es', 'de', 'ja', 'ko', 'ru', 
            'pt-br', 'tr', 'pl', 'cs', 'hu', 'zh-cn', 'zh-tw'
        ]

        print('🔄 Starting to sort message entries...\n')

        # Extract all sections
        sections = []
        for lang in languages:
            section = self.extract_language_section(lang)
            if section:
                sections.append(section)
                print(f'✅ Extracted {len(section.entries)} entries for {lang}')

        if not sections:
            print('❌ No language sections found!')
            return

        # Sort sections and rebuild file
        new_lines = self.lines.copy()
        offset = 0

        for section in sections:
            print(f'\n🔄 Sorting {section.language}...')

            # Check if already sorted
            current_keys = [entry.key for entry in section.entries]
            sorted_keys = sorted(current_keys, key=str.lower)
            is_already_sorted = current_keys == sorted_keys

            if is_already_sorted:
                print(f'✅ {section.language} is already sorted!')
                continue

            print(f'📝 Sorting {len(section.entries)} entries for {section.language}')
            print(f'   First key was: {current_keys[0]} -> now: {sorted_keys[0]}')

            # Create sorted content
            sorted_section_lines = self.create_sorted_section(section)

            # Calculate adjusted positions with offset
            adjusted_start_line = section.start_line + offset
            adjusted_end_line = section.end_line + offset
            original_section_length = adjusted_end_line - adjusted_start_line + 1

            # Replace the section in new_lines
            new_lines[adjusted_start_line:adjusted_start_line + original_section_length] = sorted_section_lines

            # Update offset for next sections
            offset += len(sorted_section_lines) - original_section_length

            print(f'✅ Sorted {section.language} successfully')

        # Write the new content
        new_content = '\n'.join(new_lines)
        backup_path = self.file_path + '.backup'

        # Create backup
        shutil.copy2(self.file_path, backup_path)
        print(f'\n💾 Created backup: {backup_path}')

        # Write sorted file
        with open(self.output_file, 'w', encoding='utf-8', newline='\n') as f:
            f.write(new_content)
        print(f'✅ File sorted successfully: {self.output_file}')

        # Summary
        print('\n📊 Summary:')
        print(f'   Languages processed: {len(sections)}')
        print(f'   Total entries per language: ~{len(sections[0].entries) if sections else 0}')
        print(f'   Backup created: {os.path.basename(backup_path)}')
        print('\n🎉 All message entries are now sorted alphabetically!')

    def verify_sorting(self) -> bool:
        """Verify the sorting was successful"""
        print('\n🔍 Verifying sorting...')

        languages = [
            'en', 'fr', 'it', 'es', 'de', 'ja', 'ko', 'ru', 
            'pt-br', 'tr', 'pl', 'cs', 'hu', 'zh-cn', 'zh-tw'
        ]
        all_sorted = True

        # Re-read the file
        with open(self.output_file, 'r', encoding='utf-8') as f:
            self.content = f.read()
        self.lines = self.content.split('\n')

        for lang in languages:
            section = self.extract_language_section(lang)
            if section:
                keys = [entry.key for entry in section.entries]
                sorted_keys = sorted(keys, key=str.lower)
                is_sorted = keys == sorted_keys

                print(f'   {lang}: {"✅ Sorted" if is_sorted else "❌ Not sorted"}')

                if not is_sorted:
                    all_sorted = False
                    print(f'      Expected: {sorted_keys[0]} ... {sorted_keys[-1]}')
                    print(f'      Got:      {keys[0]} ... {keys[-1]}')

        if all_sorted:
            print('\n🎉 All languages are properly sorted alphabetically!')
        else:
            print('\n⚠️  Some languages are not properly sorted.')
        return all_sorted
    
    def get_missing_sentences(self, src_lang:str, target_lang: str, sorted: bool = True) -> Union[List[MessageEntry], None]:
        """Extract the sentences that are not present in the target language"""
        missing_sentences: List[MessageEntry] = []
        # Re-read the file
        with open(self.output_file, 'r', encoding='utf-8') as f:
            self.content = f.read()
        self.lines = self.content.split('\n')

        src_lang_content: Union[LanguageSection, None] = self.extract_language_section(src_lang)
        dest_lang_content: Union[LanguageSection, None] = self.extract_language_section(target_lang)
        if not src_lang_content or not dest_lang_content:
            print("The src_lang_content or dest_lang_content is not present.")
            return
        print(f"Gathered src_lang_content: {src_lang_content}")
        print(f"Gathered dest_lang_content: {dest_lang_content}")
        iterA = None
        iterB = None
        if len(src_lang_content.entries) >= len(dest_lang_content.entries):
            iterA = src_lang_content
            iterB = dest_lang_content
        else:
            iterA = dest_lang_content
            iterB = src_lang_content
        for sentence_src in iterA.entries:
            sentence_found:bool = False
            for sentence_dest in iterB.entries:
                if sentence_src.key == sentence_dest.key:
                    sentence_found = True
                    break
            if sentence_found is False:
                print(f"sentence {sentence_src.key} not found in {target_lang}")
                missing_sentences.append(sentence_src)
        print(f"Final sentences not present: {missing_sentences}")
        return missing_sentences

# %%
# The main function of the program
message_file_path = Path(FILE_PATH)

if not message_file_path.exists():
    print(f'❌ File not found: {message_file_path}')
    sys.exit(1)

# %%
print(f'📁 Processing file: {message_file_path}\n')
loaded=False

try:
    sorter = MessageSorter(str(message_file_path), OUTPUT_NAME)
    loaded=True
except Exception as error:
    print(f'❌ Error occurred: {error}')
# Out:
# 📁 Processing file: /home/eletellier/Documents/001_github/Asperguide/asper-header/vscode/asperheader/src/modules/messageReference.ts

# %%
if loaded:
    # Sort all languages
    try:
        sorter.sort_all_languages()
    except Exception as error:
        print(f'❌ Error occurred: {error}')
# Out:
# 🔄 Starting to sort message entries...
#
# ✅ Extracted 139 entries for en
# ✅ Extracted 139 entries for fr
# ✅ Extracted 139 entries for it
# ✅ Extracted 139 entries for es
# ✅ Extracted 139 entries for de
# ✅ Extracted 139 entries for ja
# ✅ Extracted 139 entries for ko
# ✅ Extracted 139 entries for ru
# ✅ Extracted 139 entries for pt-br
# ✅ Extracted 139 entries for tr
# ✅ Extracted 139 entries for pl
# ✅ Extracted 139 entries for cs
# ✅ Extracted 139 entries for hu
# ✅ Extracted 139 entries for zh-cn
# ✅ Extracted 139 entries for zh-tw
#
# 🔄 Sorting en...
# 📝 Sorting 139 entries for en
#    First key was: alternateFilePathUpdated -> now: alternateFilePathUpdated
# ✅ Sorted en successfully
#
# 🔄 Sorting fr...
# ✅ fr is already sorted!
#
# 🔄 Sorting it...
# 📝 Sorting 139 entries for it
#    First key was: alternateFilePathUpdated -> now: alternateFilePathUpdated
# ✅ Sorted it successfully
#
# 🔄 Sorting es...
# ✅ es is already sorted!
#
# 🔄 Sorting de...
# 📝 Sorting 139 entries for de
#    First key was: alternateFilePathUpdated -> now: alternateFilePathUpdated
# ✅ Sorted de successfully
#
# 🔄 Sorting ja...
# 📝 Sorting 139 entries for ja
#    First key was: alternateFilePathUpdated -> now: alternateFilePathUpdated
# ✅ Sorted ja successfully
#
# 🔄 Sorting ko...
# 📝 Sorting 139 entries for ko
#    First key was: alternateFilePathUpdated -> now: alternateFilePathUpdated
# ✅ Sorted ko successfully
#
# 🔄 Sorting ru...
# 📝 Sorting 139 entries for ru
#    First key was: alternateFilePathUpdated -> now: alternateFilePathUpdated
# ✅ Sorted ru successfully
#
# 🔄 Sorting pt-br...
# 📝 Sorting 139 entries for pt-br
#    First key was: alternateFilePathUpdated -> now: alternateFilePathUpdated
# ✅ Sorted pt-br successfully
#
# 🔄 Sorting tr...
# 📝 Sorting 139 entries for tr
#    First key was: alternateFilePathUpdated -> now: alternateFilePathUpdated
# ✅ Sorted tr successfully
#
# 🔄 Sorting pl...
# 📝 Sorting 139 entries for pl
#    First key was: alternateFilePathUpdated -> now: alternateFilePathUpdated
# ✅ Sorted pl successfully
#
# 🔄 Sorting cs...
# 📝 Sorting 139 entries for cs
#    First key was: alternateFilePathUpdated -> now: alternateFilePathUpdated
# ✅ Sorted cs successfully
#
# 🔄 Sorting hu...
# 📝 Sorting 139 entries for hu
#    First key was: alternateFilePathUpdated -> now: alternateFilePathUpdated
# ✅ Sorted hu successfully
#
# 🔄 Sorting zh-cn...
# 📝 Sorting 139 entries for zh-cn
#    First key was: alternateFilePathUpdated -> now: alternateFilePathUpdated
# ✅ Sorted zh-cn successfully
#
# 🔄 Sorting zh-tw...
# 📝 Sorting 139 entries for zh-tw
#    First key was: alternateFilePathUpdated -> now: alternateFilePathUpdated
# ✅ Sorted zh-tw successfully
#
# 💾 Created backup: /home/eletellier/Documents/001_github/Asperguide/asper-header/vscode/asperheader/src/modules/messageReference.ts.backup
# ✅ File sorted successfully: /home/eletellier/Documents/001_github/Asperguide/asper-header/vscode/asperheader/src/modules/messageReference_sorted.ts
#
# 📊 Summary:
#    Languages processed: 15
#    Total entries per language: ~139
#    Backup created: messageReference.ts.backup
#
# 🎉 All message entries are now sorted alphabetically!

# %%
if loaded:
    # Verify the result
    try:
        sorter.verify_sorting()
    except Exception as error:
        print(f'❌ Error occurred: {error}')
# Out:
# 🔍 Verifying sorting...
#    en: ✅ Sorted
#    fr: ✅ Sorted
#    it: ✅ Sorted
#    es: ✅ Sorted
#    de: ✅ Sorted
#    ja: ✅ Sorted
#    ko: ✅ Sorted
#    ru: ✅ Sorted
#    pt-br: ✅ Sorted
#    tr: ✅ Sorted
#    pl: ✅ Sorted
#    cs: ✅ Sorted
#    hu: ✅ Sorted
#    zh-cn: ✅ Sorted
#    zh-tw: ✅ Sorted
#
# 🎉 All languages are properly sorted alphabetically!

# %%
languages = [
            'fr', 'it', 'es', 'de', 'ja', 'ko', 'ru', 
            'pt-br', 'tr', 'pl', 'cs', 'hu', 'zh-cn', 'zh-tw'
        ]
missing_sentences: Dict[str, Union[None, List[MessageEntry]]] = {}
if loaded:
    source_language: str = "en"
    for lang in languages:
        try:
            print(f"Checking language '{source_language}' against '{lang}'")
            missing_sentences[lang] = sorter.get_missing_sentences(source_language,lang)
        except Exception as error:
            print(f'❌ Error occurred: {error}')
# Out:
# Checking language 'en' against 'fr'
# Gathered src_lang_content: LanguageSection(language='en', start_line=332, end_line=472, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `The alternate path has been updated from ${oldFilePath} to ${newFilePath}.`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "Not Provided"): string => `The alternate logo root directory \'${alternateRootDirectory}\' was not found, error: \'${error}\'.`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: (): string => `No alternate logo directory provided.`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]): string => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}.`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Asper Header Booting up",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: (): string => "Broken header detected, injecting new one, please remove the previous one.",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "The cache is already loaded, returning stored instance.",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: (): string => "Please select your preferred comment prefix from the options below:",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "Classes initialised",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} initialised`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: (): string => "The document is closed, stopping operations.",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "The description was provided in the configuration, using it and skipping user prompting.",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `Converted content: ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "Converted content: ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: (): string => "The required file meta data appears to not have been gathered correctly, aborting.",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "Current working directories set",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string): string => `The provided current working directory ${cwd} does not exist.`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string): string => `The current working directory referential has been updated from ${oldCwd} to ${newCwd}.`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: (): string => "Age",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: (): string => "Alias",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string): string => `ASCII art copied for ${name}!`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: (): string => "Copy ASCII",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: (): string => "Description",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: (): string => "Height",'), MessageEntry(key='darlingImage', full_content='        darlingImage: (): string => "Image",'), MessageEntry(key='darlingJsonFileInvalid',  ...
# Gathered dest_lang_content: LanguageSection(language='fr', start_line=473, end_line=613, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `Le chemin alternatif a été mis à jour de ${oldFilePath} vers ${newFilePath}.`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "Non fourni") => `Le répertoire racine du logo alternatif \'${alternateRootDirectory}\' est introuvable, erreur : \'${error}\'.`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: () => `Aucun répertoire de logo alternatif n’a été fourni.`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]): string => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}.`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Asper Header démarrage",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: (): string => "En-tête corrompu détecté, injection d’un nouveau, veuillez supprimer l’ancien.",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "Le cache est déjà chargé, retour de l\'instance stockée.",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: (): string => "Veuillez sélectionner votre préfixe de commentaire préféré parmi les options ci-dessous :",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "Classes initialisées",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} initialisé`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: (): string => "Le document est fermé, arrêt des opérations.",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "La description a été fournie dans la configuration, utilisation de celle-ci et passage de la demande à l\'utilisateur.",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `Contenu converti : ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "Contenu converti : ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: (): string => "Les métadonnées nécessaires du fichier n’ont pas été correctement collectées, abandon.",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "Répertoires de travail actuels définis",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string): string => `Le répertoire de travail fourni ${cwd} n’existe pas.`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string): string => `Le répertoire de travail a été mis à jour de ${oldCwd} vers ${newCwd}.`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: (): string => "Âge",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: (): string => "Alias",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string): string => `Art ASCII copié pour ${name} !`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: (): string => "Copier l\'ASCII",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: (): string => "Description",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: (): string => "Taille",'), MessageEntry(key='darlingImage', full_content='        darlingImage: (): string => ...
# Final sentences not present: []
# Checking language 'en' against 'it'
# Gathered src_lang_content: LanguageSection(language='en', start_line=332, end_line=472, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `The alternate path has been updated from ${oldFilePath} to ${newFilePath}.`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "Not Provided"): string => `The alternate logo root directory \'${alternateRootDirectory}\' was not found, error: \'${error}\'.`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: (): string => `No alternate logo directory provided.`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]): string => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}.`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Asper Header Booting up",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: (): string => "Broken header detected, injecting new one, please remove the previous one.",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "The cache is already loaded, returning stored instance.",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: (): string => "Please select your preferred comment prefix from the options below:",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "Classes initialised",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} initialised`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: (): string => "The document is closed, stopping operations.",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "The description was provided in the configuration, using it and skipping user prompting.",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `Converted content: ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "Converted content: ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: (): string => "The required file meta data appears to not have been gathered correctly, aborting.",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "Current working directories set",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string): string => `The provided current working directory ${cwd} does not exist.`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string): string => `The current working directory referential has been updated from ${oldCwd} to ${newCwd}.`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: (): string => "Age",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: (): string => "Alias",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string): string => `ASCII art copied for ${name}!`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: (): string => "Copy ASCII",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: (): string => "Description",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: (): string => "Height",'), MessageEntry(key='darlingImage', full_content='        darlingImage: (): string => "Image",'), MessageEntry(key='darlingJsonFileInvalid',  ...
# Gathered dest_lang_content: LanguageSection(language='it', start_line=614, end_line=754, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `Il percorso alternativo è stato aggiornato da ${oldFilePath} a ${newFilePath}.`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "Non fornito") => `La directory principale del logo alternativo \'${alternateRootDirectory}\' non è stata trovata, errore: \'${error}\'.`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: () => `Nessuna directory alternativa del logo fornita.`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]): string => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}.`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Avvio di Asper Header",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: (): string => "Intestazione danneggiata rilevata, iniezione di una nuova, si prega di rimuovere la precedente.",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "La cache è già stata caricata, restituzione dell\'istanza memorizzata.",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: (): string => "Seleziona il prefisso di commento preferito dalle opzioni qui sotto:",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "Classi inizializzate",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} inizializzato`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: (): string => "Il documento è chiuso, operazioni interrotte.",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "La descrizione è stata fornita nella configurazione, viene utilizzata e si salta la richiesta all\'utente.",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `Contenuto convertito: ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "Contenuto convertito: ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: (): string => "I metadati richiesti del file non sono stati raccolti correttamente, interruzione.",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "Directory di lavoro correnti impostate",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string): string => `La directory di lavoro fornita ${cwd} non esiste.`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string): string => `La directory di lavoro è stata aggiornata da ${oldCwd} a ${newCwd}.`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: (): string => "Età",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: (): string => "Alias",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string): string => `Arte ASCII copiata per ${name}!`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: (): string => "Copia ASCII",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: (): string => "Descrizione",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: (): string => "Altezza",'), MessageEntry(key='darlingImage', full_content='        darlingImage: (): string  ...
# Final sentences not present: []
# Checking language 'en' against 'es'
# Gathered src_lang_content: LanguageSection(language='en', start_line=332, end_line=472, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `The alternate path has been updated from ${oldFilePath} to ${newFilePath}.`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "Not Provided"): string => `The alternate logo root directory \'${alternateRootDirectory}\' was not found, error: \'${error}\'.`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: (): string => `No alternate logo directory provided.`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]): string => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}.`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Asper Header Booting up",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: (): string => "Broken header detected, injecting new one, please remove the previous one.",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "The cache is already loaded, returning stored instance.",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: (): string => "Please select your preferred comment prefix from the options below:",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "Classes initialised",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} initialised`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: (): string => "The document is closed, stopping operations.",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "The description was provided in the configuration, using it and skipping user prompting.",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `Converted content: ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "Converted content: ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: (): string => "The required file meta data appears to not have been gathered correctly, aborting.",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "Current working directories set",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string): string => `The provided current working directory ${cwd} does not exist.`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string): string => `The current working directory referential has been updated from ${oldCwd} to ${newCwd}.`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: (): string => "Age",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: (): string => "Alias",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string): string => `ASCII art copied for ${name}!`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: (): string => "Copy ASCII",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: (): string => "Description",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: (): string => "Height",'), MessageEntry(key='darlingImage', full_content='        darlingImage: (): string => "Image",'), MessageEntry(key='darlingJsonFileInvalid',  ...
# Gathered dest_lang_content: LanguageSection(language='es', start_line=755, end_line=895, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `La ruta alternativa se ha actualizado de ${oldFilePath} a ${newFilePath}.`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "No proporcionado") => `No se encontró el directorio raíz del logotipo alternativo \'${alternateRootDirectory}\', error: \'${error}\'.`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: () => `No se ha proporcionado un directorio de logotipos alternativo.`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]): string => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}.`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Iniciando Asper Header",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: (): string => "Encabezado roto detectado, inyectando uno nuevo, por favor elimina el anterior.",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "La caché ya está cargada, devolviendo la instancia almacenada.",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: (): string => "Seleccione su prefijo de comentario preferido de las opciones a continuación:",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "Clases inicializadas",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} inicializado`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: (): string => "El documento está cerrado, deteniendo operaciones.",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "La descripción fue proporcionada en la configuración, se usará y se omitirá la solicitud al usuario.",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `Contenido convertido: ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "Contenido convertido: ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: (): string => "Los metadatos del archivo no se recopilaron correctamente, abortando.",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "Directorios de trabajo actuales establecidos",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string): string => `El directorio de trabajo proporcionado ${cwd} no existe.`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string): string => `El directorio de trabajo se actualizó de ${oldCwd} a ${newCwd}.`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: (): string => "Edad",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: (): string => "Alias",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string): string => `Arte ASCII copiado para ${name}!`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: (): string => "Copiar ASCII",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: (): string => "Descripción",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: (): string => "Altura",'), MessageEntry(key='darlingImage', full_content='        darlingImage: (): string => "Imagen ...
# Final sentences not present: []
# Checking language 'en' against 'de'
# Gathered src_lang_content: LanguageSection(language='en', start_line=332, end_line=472, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `The alternate path has been updated from ${oldFilePath} to ${newFilePath}.`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "Not Provided"): string => `The alternate logo root directory \'${alternateRootDirectory}\' was not found, error: \'${error}\'.`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: (): string => `No alternate logo directory provided.`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]): string => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}.`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Asper Header Booting up",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: (): string => "Broken header detected, injecting new one, please remove the previous one.",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "The cache is already loaded, returning stored instance.",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: (): string => "Please select your preferred comment prefix from the options below:",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "Classes initialised",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} initialised`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: (): string => "The document is closed, stopping operations.",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "The description was provided in the configuration, using it and skipping user prompting.",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `Converted content: ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "Converted content: ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: (): string => "The required file meta data appears to not have been gathered correctly, aborting.",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "Current working directories set",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string): string => `The provided current working directory ${cwd} does not exist.`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string): string => `The current working directory referential has been updated from ${oldCwd} to ${newCwd}.`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: (): string => "Age",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: (): string => "Alias",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string): string => `ASCII art copied for ${name}!`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: (): string => "Copy ASCII",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: (): string => "Description",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: (): string => "Height",'), MessageEntry(key='darlingImage', full_content='        darlingImage: (): string => "Image",'), MessageEntry(key='darlingJsonFileInvalid',  ...
# Gathered dest_lang_content: LanguageSection(language='de', start_line=896, end_line=1036, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `Der alternative Pfad wurde von ${oldFilePath} auf ${newFilePath} aktualisiert.`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "Nicht angegeben") => `Das alternative Logo-Stammverzeichnis \'${alternateRootDirectory}\' wurde nicht gefunden, Fehler: \'${error}\'.`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: () => `Kein alternatives Logo-Verzeichnis angegeben.`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]) => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}.`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Asper Header wird gestartet",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: () => "Beschädigter Header erkannt, füge neuen Header ein, bitte vorherigen entfernen.",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "Der Cache ist bereits geladen, gespeicherte Instanz wird zurückgegeben.",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: () => "Bitte bevorzugten Kommentarpräfix aus den Optionen unten auswählen:",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "Klassen initialisiert",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} initialisiert`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: () => "Das Dokument ist geschlossen, Operationen gestoppt.",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "Die Beschreibung wurde in der Konfiguration angegeben, sie wird verwendet und die Benutzerabfrage wird übersprungen.",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `Konvertierter Inhalt: ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "Konvertierter Inhalt: ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: () => "Datei-Metadaten wurden nicht korrekt gesammelt, Abbruch.",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "Aktuelle Arbeitsverzeichnisse gesetzt",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string) => `Das angegebene Arbeitsverzeichnis ${cwd} existiert nicht.`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string) => `Das aktuelle Arbeitsverzeichnis wurde von ${oldCwd} auf ${newCwd} aktualisiert.`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: () => "Alter",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: () => "Alias",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string) => `ASCII-Kunst für ${name} kopiert!`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: () => "ASCII kopieren",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: () => "Beschreibung",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: () => "Größe",'), MessageEntry(key='darlingImage', full_content='        darlingImage: () => "Bild",'), MessageEntry(key='darlingJsonFileInvalid', full_content='        darlingJsonFileInvalid: () => " ...
# Final sentences not present: []
# Checking language 'en' against 'ja'
# Gathered src_lang_content: LanguageSection(language='en', start_line=332, end_line=472, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `The alternate path has been updated from ${oldFilePath} to ${newFilePath}.`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "Not Provided"): string => `The alternate logo root directory \'${alternateRootDirectory}\' was not found, error: \'${error}\'.`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: (): string => `No alternate logo directory provided.`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]): string => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}.`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Asper Header Booting up",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: (): string => "Broken header detected, injecting new one, please remove the previous one.",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "The cache is already loaded, returning stored instance.",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: (): string => "Please select your preferred comment prefix from the options below:",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "Classes initialised",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} initialised`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: (): string => "The document is closed, stopping operations.",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "The description was provided in the configuration, using it and skipping user prompting.",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `Converted content: ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "Converted content: ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: (): string => "The required file meta data appears to not have been gathered correctly, aborting.",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "Current working directories set",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string): string => `The provided current working directory ${cwd} does not exist.`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string): string => `The current working directory referential has been updated from ${oldCwd} to ${newCwd}.`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: (): string => "Age",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: (): string => "Alias",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string): string => `ASCII art copied for ${name}!`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: (): string => "Copy ASCII",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: (): string => "Description",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: (): string => "Height",'), MessageEntry(key='darlingImage', full_content='        darlingImage: (): string => "Image",'), MessageEntry(key='darlingJsonFileInvalid',  ...
# Gathered dest_lang_content: LanguageSection(language='ja', start_line=1037, end_line=1177, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `代替パスが ${oldFilePath} から ${newFilePath} に更新されました。`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "未提供") => `代替ロゴのルートディレクトリ \'${alternateRootDirectory}\' が見つかりません、エラー: \'${error}\'。`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: () => `代替ロゴディレクトリが指定されていません。`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]) => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}。`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Asper Header 起動中",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: () => "壊れたヘッダーが検出されました。新しいヘッダーを挿入します。前のものを削除してください。",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "キャッシュはすでに読み込まれています。保存されたインスタンスを返します。",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: () => "以下のオプションからコメントのプレフィックスを選択してください: ",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "クラスが初期化されました",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} が初期化されました`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: () => "ドキュメントは閉じられました。操作を停止します。",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "設定で説明が提供されたため、それを使用し、ユーザーへのプロンプトをスキップします。",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `変換された内容: ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "変換された内容: ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: () => "必要なファイルメタデータが正しく収集されていません。中止します。",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "現在の作業ディレクトリが設定されました",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string) => `指定された作業ディレクトリ ${cwd} は存在しません。`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string) => `現在の作業ディレクトリを ${oldCwd} から ${newCwd} に更新しました。`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: () => "年齢",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: () => "別名",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string) => `${name} の ASCII アートをコピーしました！`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: () => "ASCII をコピー",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: () => "説明",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: () => "身長",'), MessageEntry(key='darlingImage', full_content='        darlingImage: () => "画像",'), MessageEntry(key='darlingJsonFileInvalid', full_content='        darlingJsonFileInvalid: () => "Darling JSON ファイルが空または無効です",'), MessageEntry(key='darlingMoreInfo', full_content='        darlingMoreInfo: () => "詳細情報",'), MessageEntry(key='darlingPersonDisplayed', full_content="        darlingPersonDisplayed: (name: string) => `キャラクター '${name}' を表示しました。`,"), MessageEntry(key='darlingQuote', full_content='        darlingQuote: () => "引用",'), MessageEntry(key='darlingType', full_content='        darlingType: () => "タイプ",'), MessageEntry(key='darlingView', full_content='        darlingVie ...
# Final sentences not present: []
# Checking language 'en' against 'ko'
# Gathered src_lang_content: LanguageSection(language='en', start_line=332, end_line=472, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `The alternate path has been updated from ${oldFilePath} to ${newFilePath}.`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "Not Provided"): string => `The alternate logo root directory \'${alternateRootDirectory}\' was not found, error: \'${error}\'.`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: (): string => `No alternate logo directory provided.`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]): string => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}.`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Asper Header Booting up",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: (): string => "Broken header detected, injecting new one, please remove the previous one.",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "The cache is already loaded, returning stored instance.",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: (): string => "Please select your preferred comment prefix from the options below:",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "Classes initialised",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} initialised`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: (): string => "The document is closed, stopping operations.",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "The description was provided in the configuration, using it and skipping user prompting.",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `Converted content: ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "Converted content: ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: (): string => "The required file meta data appears to not have been gathered correctly, aborting.",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "Current working directories set",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string): string => `The provided current working directory ${cwd} does not exist.`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string): string => `The current working directory referential has been updated from ${oldCwd} to ${newCwd}.`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: (): string => "Age",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: (): string => "Alias",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string): string => `ASCII art copied for ${name}!`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: (): string => "Copy ASCII",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: (): string => "Description",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: (): string => "Height",'), MessageEntry(key='darlingImage', full_content='        darlingImage: (): string => "Image",'), MessageEntry(key='darlingJsonFileInvalid',  ...
# ...
# Gathered dest_lang_content: LanguageSection(language='zh-cn', start_line=2165, end_line=2305, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `备用路径已从 ${oldFilePath} 更新为 ${newFilePath}。`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "未提供") => `未找到备用徽标根目录 \'${alternateRootDirectory}\'，错误: \'${error}\'。`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: () => `未提供备用徽标目录。`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]) => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}。`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Asper Header 启动中",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: () => "检测到破损的头部，正在注入新的，请删除旧的。",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "缓存已加载，返回存储的实例。",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: () => "请选择以下选项中的首选注释前缀：",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "类已初始化",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} 已初始化`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: () => "文档已关闭，停止操作。",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "配置中已提供描述，将使用该描述并跳过用户提示。",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `转换后的内容: ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "转换后的内容: ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: () => "文件元数据未正确收集，中止操作。",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "当前工作目录已设置",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string) => `提供的工作目录 ${cwd} 不存在。`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string) => `当前工作目录已从 ${oldCwd} 更新为 ${newCwd}。`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: () => "年龄",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: () => "别名",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string) => `${name} 的 ASCII 艺术已复制！`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: () => "复制 ASCII",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: () => "描述",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: () => "身高",'), MessageEntry(key='darlingImage', full_content='        darlingImage: () => "图像",'), MessageEntry(key='darlingJsonFileInvalid', full_content='        darlingJsonFileInvalid: () => "Darling JSON 文件为空或无效",'), MessageEntry(key='darlingMoreInfo', full_content='        darlingMoreInfo: () => "更多信息",'), MessageEntry(key='darlingPersonDisplayed', full_content="        darlingPersonDisplayed: (name: string) => `角色 '${name}' 已显示。`,"), MessageEntry(key='darlingQuote', full_content='        darlingQuote: () => "引用",'), MessageEntry(key='darlingType', full_content='        darlingType: () => "类型",'), MessageEntry(key='darlingView', full_content='        darlingView: () => "角色视图",'), MessageEntry(key='darlingZoomIn', full_content='        darlingZoomIn: () => "放大",'), MessageEntry(key='darlingZoomOut', full_content='        darlingZoomOut: () => "缩小",'), MessageEntr ...
# Final sentences not present: []
# Checking language 'en' against 'zh-tw'
# Gathered src_lang_content: LanguageSection(language='en', start_line=332, end_line=472, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `The alternate path has been updated from ${oldFilePath} to ${newFilePath}.`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "Not Provided"): string => `The alternate logo root directory \'${alternateRootDirectory}\' was not found, error: \'${error}\'.`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: (): string => `No alternate logo directory provided.`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]): string => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}.`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Asper Header Booting up",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: (): string => "Broken header detected, injecting new one, please remove the previous one.",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "The cache is already loaded, returning stored instance.",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: (): string => "Please select your preferred comment prefix from the options below:",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "Classes initialised",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} initialised`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: (): string => "The document is closed, stopping operations.",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "The description was provided in the configuration, using it and skipping user prompting.",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `Converted content: ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "Converted content: ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: (): string => "The required file meta data appears to not have been gathered correctly, aborting.",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "Current working directories set",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string): string => `The provided current working directory ${cwd} does not exist.`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string): string => `The current working directory referential has been updated from ${oldCwd} to ${newCwd}.`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: (): string => "Age",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: (): string => "Alias",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string): string => `ASCII art copied for ${name}!`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: (): string => "Copy ASCII",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: (): string => "Description",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: (): string => "Height",'), MessageEntry(key='darlingImage', full_content='        darlingImage: (): string => "Image",'), MessageEntry(key='darlingJsonFileInvalid',  ...
# Gathered dest_lang_content: LanguageSection(language='zh-tw', start_line=2306, end_line=2446, entries=[MessageEntry(key='alternateFilePathUpdated', full_content='        alternateFilePathUpdated: (oldFilePath: string, newFilePath: string): string => `替代路徑已從 ${oldFilePath} 更新為 ${newFilePath}。`,'), MessageEntry(key='alternateLogoDirectoryNotFound', full_content='        alternateLogoDirectoryNotFound: (alternateRootDirectory: string, error: string = "未提供") => `找不到替代的標誌根目錄 \'${alternateRootDirectory}\'，錯誤: \'${error}\'。`,'), MessageEntry(key='alternateLogoDirectoryNotProvided', full_content='        alternateLogoDirectoryNotProvided: () => `未提供替代的標誌目錄。`,'), MessageEntry(key='arrayNodeContent', full_content='        arrayNodeContent: (arrayName: string, arrayIndex: number, arrayNode: any[]) => `${arrayName}[${arrayIndex}] = ${JSON.stringify(arrayNode)}。`,'), MessageEntry(key='bootingUp', full_content='        bootingUp: (): string => "Asper Header 啟動中",'), MessageEntry(key='brokenHeader', full_content='        brokenHeader: () => "檢測到破損的頭部，正在注入新的，請刪除舊的。",'), MessageEntry(key='cacheAlreadyLoaded', full_content='        cacheAlreadyLoaded: (): string => "快取已載入，返回儲存的實例。",'), MessageEntry(key='chooseSingleLineCommentOption', full_content='        chooseSingleLineCommentOption: () => "請從下列選項中選擇首選註解前綴：",'), MessageEntry(key='classesInitialised', full_content='        classesInitialised: (): string => "類別已初始化",'), MessageEntry(key='classInitialised', full_content='        classInitialised: (moduleName: string, className: string): string => `>>> ${className}: ${moduleName} 已初始化`,'), MessageEntry(key='closedDocument', full_content='        closedDocument: () => "文件已關閉，停止操作。",'), MessageEntry(key='configDescriptionUsed', full_content='        configDescriptionUsed: (): string => "在設定中已提供描述，將使用該描述並跳過使用者提示。",'), MessageEntry(key='convertedContentCli', full_content='        convertedContentCli: (content: string): string => `轉換後的內容: ${content}`,'), MessageEntry(key='convertedContentGui', full_content='        convertedContentGui: (): string => "轉換後的內容: ",'), MessageEntry(key='corruptedFileMetaData', full_content='        corruptedFileMetaData: () => "檔案元資料未正確收集，中止操作。",'), MessageEntry(key='currentWorkingDirectorySet', full_content='        currentWorkingDirectorySet: (): string => "目前工作目錄已設定",'), MessageEntry(key='cwdDoesNotExist', full_content='        cwdDoesNotExist: (cwd: string) => `提供的工作目錄 ${cwd} 不存在。`,'), MessageEntry(key='cwdUpdated', full_content='        cwdUpdated: (oldCwd: string, newCwd: string) => `當前工作目錄已從 ${oldCwd} 更新為 ${newCwd}。`,'), MessageEntry(key='darlingAge', full_content='        darlingAge: () => "年齡",'), MessageEntry(key='darlingAlias', full_content='        darlingAlias: () => "別名",'), MessageEntry(key='darlingCopied', full_content='        darlingCopied: (name: string) => `${name} 的 ASCII 藝術已複製！`,'), MessageEntry(key='darlingCopyAscii', full_content='        darlingCopyAscii: () => "複製 ASCII",'), MessageEntry(key='darlingDescription', full_content='        darlingDescription: () => "描述",'), MessageEntry(key='darlingHeight', full_content='        darlingHeight: () => "身高",'), MessageEntry(key='darlingImage', full_content='        darlingImage: () => "圖片",'), MessageEntry(key='darlingJsonFileInvalid', full_content='        darlingJsonFileInvalid: () => "Darling JSON 檔案為空或無效",'), MessageEntry(key='darlingMoreInfo', full_content='        darlingMoreInfo: () => "更多資訊",'), MessageEntry(key='darlingPersonDisplayed', full_content="        darlingPersonDisplayed: (name: string) => `角色 '${name}' 已顯示。`,"), MessageEntry(key='darlingQuote', full_content='        darlingQuote: () => "引用",'), MessageEntry(key='darlingType', full_content='        darlingType: () => "類型",'), MessageEntry(key='darlingView', full_content='        darlingView: () => "角色檢視",'), MessageEntry(key='darlingZoomIn', full_content='        darlingZoomIn: () => "放大",'), MessageEntry(key='darlingZoomOut', full_content='        darlingZoomOut: () => "縮小",'), Messag ...
# Final sentences not present: []

# %%
# Displaying missing sentences per language
for key, value in missing_sentences.items():
    if not value:
        print(f"{key}: {value}")
    else:
        print(f"{key}:")
        for i in value:
            print(f"\t{i.full_content}")
# Out:
# fr: []
# it: []
# es: []
# de: []
# ja: []
# ko: []
# ru: []
# pt-br: []
# tr: []
# pl: []
# cs: []
# hu: []
# zh-cn: []
# zh-tw: []
